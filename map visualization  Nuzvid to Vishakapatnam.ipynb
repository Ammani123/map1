# %%
import folium

# %%
way1=[[16.7850,80.8488],[16.7107,81.0952],[17.0005,81.8040],[17.2789,82.4013],[17.3573,82.5443],[17.4825,82.4888],[17.5690,82.4924]]
way2=[[16.7850,80.8488],[16.6356,80.9716],[17.0005,81.8040],[17.2789,82.4013],[17.3573,82.5443],[17.5690,82.4924]]

# %%
from branca.element import Figure
fig=Figure(width=550,height=350)

# %%
f1=folium.FeatureGroup("transportation way1")
f2=folium.FeatureGroup("transportation way2")
map=folium.Map(location=[16.7850,80.8488],title='cartodbpositron')
line_1=folium.vector_layers.PolyLine(way1,popup='<b>Path of Vehicle_1</b>',tooltip='Vehicle_1',color='green',weight=10).add_to(f1)
line_2=folium.vector_layers.PolyLine(way2,popup='<b>Path of Vehicle_1</b>',tooltip='Vehicle_1',color='red',weight=10).add_to(f2)
f1.add_to(map)
f2.add_to(map)
folium.Marker(location=[16.780001,80.849998],popup='starting location',tooltip='Nuzvid',icon=folium.Icon(color='purple',prefix='fa',icon='train')).add_to(map)
folium.Marker(location=[16.7107,81.0952],popup='2nd location',tooltip='Eluru',icon=folium.Icon(color='red',prefix='fa',icon='plus')).add_to(map)
folium.Marker(location=[17.0005,81.8040],popup='3rd location',tooltip='Rajamahendravaram',icon=folium.Icon(color='blue',prefix='fa',icon='university')).add_to(map)
folium.Marker(location=[17.2789,82.4013],popup='4th location',tooltip='Annavaram',icon=folium.Icon(color='green',prefix='fa',icon='tree')).add_to(map)
folium.Marker(location=[17.3573,82.5443],popup='5th location',tooltip='Tuni',icon=folium.Icon(color='pink',prefix='fa',icon='stethoscope')).add_to(map)
folium.Marker(location=[17.4825,82.4888],popup='6th location',tooltip='Kotananduru',icon=folium.Icon(color='green',prefix='fa',icon='bell')).add_to(map)
folium.Marker(location=[17.5690,82.4924],popup='Destination location',icon=folium.Icon(color='purple',prefix='fa',icon='home')).add_to(map)
#way2 markers
folium.Marker(location=[16.6356,80.9716],popup='2nd location',tooltip='Hanuman Junction',icon=folium.Icon(color='orange',prefix='fa',icon='bus')).add_to(map)
map
folium.LayerControl().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
folium.Marker(location=[16.780001,80.849998],popup='starting location',tooltip='nuzvid').add_to(map)
folium.LayerControl().add_to(map)
map

# %%
#Adding markers to the map
folium.Marker(location=[16.7850,80.8488],popup='Default popup Marker1',tooltip='Click here to see more details').add_to(map)
folium.Marker(location=[16.7107,81.0952],popup='<strong>Marker3</strong>',tooltip='<strong>Click here to see Popup</strong>').add_to(map)
folium.Marker(location=[17.0005,81.8040],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>Click here to see Guntur</strong>').add_to(map)
folium.Marker(location=[17.2789,82.4013],popup='Default popup Marker1',tooltip='Click here to see more details').add_to(map)
folium.Marker(location=[17.3573,82.5443],popup='<strong>Marker3</strong>',tooltip='<strong>Click here to see Popup</strong>').add_to(map)
folium.Marker(location=[17.4825,82.4888],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>Click here to see Guntur</strong>').add_to(map)
folium.Marker(location=[17.5690,82.4924],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>Click here to see Guntur</strong>').add_to(map)
map
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
